# %% [markdown]
# <!-- # CS224V Fall 2025 HW1: Autonomous Research Agents
#
# ## From Literature Search to Investigative Analysis
#
# > **Reference:** This notebook implements the coding exercises described in the [**CS224V HW1 Handout**](handout/cs224v_hw1_handout.tex). Please refer to the handout for detailed background, theory, and implementation context.
#
# ### Assignment Overview
# This assignment involves building a **Deep Research Lite (DRLite)** system that progresses through two main phases:
# - **Foundation Building Blocks:** RAG Systems and Autonomous Literature Search
# - **Investigative Research:** Database Exploration and Automated Report Synthesis
#
# --- -->

# %% [markdown]
# # Rare & Oprhan Diseases - RAG & Article Generation

# %% [markdown]
# ### Environment configuration

# %%
# run this cell if you haven't installed the requirements
! pip install -r requirements.txt
! playwright install
# Out:
# Requirement already satisfied: dspy-ai==3.0.3 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: crawl4ai==0.7.4 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (0.7.4)
# Requirement already satisfied: langchain_text_splitters==0.3.11 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (0.3.11)
# Requirement already satisfied: jupyter==1.0.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: nbconvert[webpdf] in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (7.16.6)
# Requirement already satisfied: dspy>=3.0.3 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from dspy-ai==3.0.3->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: aiofiles>=24.1.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (24.1.0)
# Requirement already satisfied: aiohttp>=3.11.11 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (3.12.15)
# Requirement already satisfied: aiosqlite~=0.20 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (0.21.0)
# Requirement already satisfied: anyio>=4.0.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (4.11.0)
# Requirement already satisfied: lxml~=5.3 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (5.4.0)
# Requirement already satisfied: litellm>=1.53.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (1.77.4)
# Requirement already satisfied: numpy<3,>=1.26.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: pillow>=10.4 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: playwright>=1.49.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (1.55.0)
# Requirement already satisfied: patchright>=1.49.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (1.55.2)
# Requirement already satisfied: python-dotenv~=1.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: requests~=2.26 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (2.32.5)
# Requirement already satisfied: beautifulsoup4~=4.12 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (4.13.5)
# Requirement already satisfied: tf-playwright-stealth>=1.1.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: xxhash~=3.4 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: rank-bm25~=0.2 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: snowballstemmer~=2.2 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (2.2.0)
# Requirement already satisfied: pydantic>=2.10 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (2.11.9)
# Requirement already satisfied: pyOpenSSL>=24.3.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (25.3.0)
# Requirement already satisfied: psutil>=6.1.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (7.1.0)
# Requirement already satisfied: PyYAML>=6.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: nltk>=3.9.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (3.9.1)
# Requirement already satisfied: rich>=13.9.4 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (14.1.0)
# Requirement already satisfied: httpx>=0.27.2 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: fake-useragent>=2.0.3 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (2.2.0)
# Requirement already satisfied: click>=8.1.7 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (8.3.0)
# Requirement already satisfied: chardet>=5.2.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (5.2.0)
# Requirement already satisfied: brotli>=1.1.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: humanize>=4.10.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (4.13.0)
# Requirement already satisfied: lark>=1.2.2 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: alphashape>=1.3.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: shapely>=2.0.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from crawl4ai==0.7.4->-r requirements.txt (line 2)) (2.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.75 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from langchain_text_splitters==0.3.11->-r requirements.txt (line 3)) (0.3.76)
# Requirement already satisfied: notebook in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyter==1.0.0->-r requirements.txt (line 4)) (7.4.5)
# Requirement already satisfied: qtconsole in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyter==1.0.0->-r requirements.txt (line 4)) (5.7.0)
# Requirement already satisfied: jupyter-console in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyter==1.0.0->-r requirements.txt (line 4)) (6.6.3)
# Requirement already satisfied: ipykernel in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyter==1.0.0->-r requirements.txt (line 4)) (6.30.1)
# Requirement already satisfied: ipywidgets in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyter==1.0.0->-r requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: typing_extensions>=4.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from aiosqlite~=0.20->crawl4ai==0.7.4->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from beautifulsoup4~=4.12->crawl4ai==0.7.4->-r requirements.txt (line 2)) (2.8)
# Requirement already satisfied: langsmith>=0.3.45 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain_text_splitters==0.3.11->-r requirements.txt (line 3)) (0.4.31)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain_text_splitters==0.3.11->-r requirements.txt (line 3)) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain_text_splitters==0.3.11->-r requirements.txt (line 3)) (1.33)
# Requirement already satisfied: packaging>=23.2 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain_text_splitters==0.3.11->-r requirements.txt (line 3)) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<2.0.0,>=0.3.75->langchain_text_splitters==0.3.11->-r requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from requests~=2.26->crawl4ai==0.7.4->-r requirements.txt (line 2)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from requests~=2.26->crawl4ai==0.7.4->-r requirements.txt (line 2)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from requests~=2.26->crawl4ai==0.7.4->-r requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from requests~=2.26->crawl4ai==0.7.4->-r requirements.txt (line 2)) (2025.8.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert[webpdf]->-r requirements.txt (line 5)) (6.2.0)
# Requirement already satisfied: defusedxml in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from nbconvert[webpdf]->-r requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from nbconvert[webpdf]->-r requirements.txt (line 5)) (3.1.6)
# Requirement already satisfied: jupyter-core>=4.7 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from nbconvert[webpdf]->-r requirements.txt (line 5)) (5.8.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from nbconvert[webpdf]->-r requirements.txt (line 5)) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from nbconvert[webpdf]->-r requirements.txt (line 5)) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from nbconvert[webpdf]->-r requirements.txt (line 5)) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from nbconvert[webpdf]->-r requirements.txt (line 5)) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from nbconvert[webpdf]->-r requirements.txt (line 5)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from nbconvert[webpdf]->-r requirements.txt (line 5)) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from nbconvert[webpdf]->-r requirements.txt (line 5)) (2.19.2)
# Requirement already satisfied: traitlets>=5.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from nbconvert[webpdf]->-r requirements.txt (line 5)) (5.14.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from aiohttp>=3.11.11->crawl4ai==0.7.4->-r requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from aiohttp>=3.11.11->crawl4ai==0.7.4->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from aiohttp>=3.11.11->crawl4ai==0.7.4->-r requirements.txt (line 2)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from aiohttp>=3.11.11->crawl4ai==0.7.4->-r requirements.txt (line 2)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from aiohttp>=3.11.11->crawl4ai==0.7.4->-r requirements.txt (line 2)) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from aiohttp>=3.11.11->crawl4ai==0.7.4->-r requirements.txt (line 2)) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from aiohttp>=3.11.11->crawl4ai==0.7.4->-r requirements.txt (line 2)) (1.20.1)
# Requirement already satisfied: click-log>=0.3.2 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from alphashape>=1.3.1->crawl4ai==0.7.4->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: trimesh>=3.9.8 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from alphashape>=1.3.1->crawl4ai==0.7.4->-r requirements.txt (line 2)) (4.8.2)
# Requirement already satisfied: networkx>=2.5 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from alphashape>=1.3.1->crawl4ai==0.7.4->-r requirements.txt (line 2)) (3.5)
# Requirement already satisfied: rtree>=0.9.7 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from alphashape>=1.3.1->crawl4ai==0.7.4->-r requirements.txt (line 2)) (1.4.1)
# Requirement already satisfied: scipy>=1.0.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from alphashape>=1.3.1->crawl4ai==0.7.4->-r requirements.txt (line 2)) (1.16.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from anyio>=4.0.0->crawl4ai==0.7.4->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: webencodings in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert[webpdf]->-r requirements.txt (line 5)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert[webpdf]->-r requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: backoff>=2.2 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from dspy>=3.0.3->dspy-ai==3.0.3->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: joblib~=1.3 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from dspy>=3.0.3->dspy-ai==3.0.3->-r requirements.txt (line 1)) (1.5.2)
# Requirement already satisfied: openai>=0.28.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from dspy>=3.0.3->dspy-ai==3.0.3->-r requirements.txt (line 1)) (1.109.1)
# Requirement already satisfied: regex>=2023.10.3 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from dspy>=3.0.3->dspy-ai==3.0.3->-r requirements.txt (line 1)) (2025.9.18)
# Requirement already satisfied: orjson>=3.9.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from dspy>=3.0.3->dspy-ai==3.0.3->-r requirements.txt (line 1)) (3.11.3)
# Requirement already satisfied: tqdm>=4.66.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from dspy>=3.0.3->dspy-ai==3.0.3->-r requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: optuna>=3.4.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from dspy>=3.0.3->dspy-ai==3.0.3->-r requirements.txt (line 1)) (4.5.0)
# Requirement already satisfied: magicattr>=0.1.6 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from dspy>=3.0.3->dspy-ai==3.0.3->-r requirements.txt (line 1)) (0.1.6)
# Requirement already satisfied: diskcache>=5.6.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from dspy>=3.0.3->dspy-ai==3.0.3->-r requirements.txt (line 1)) (5.6.3)
# Requirement already satisfied: json-repair>=0.30.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from dspy>=3.0.3->dspy-ai==3.0.3->-r requirements.txt (line 1)) (0.51.0)
# Requirement already satisfied: asyncer==0.0.8 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from dspy>=3.0.3->dspy-ai==3.0.3->-r requirements.txt (line 1)) (0.0.8)
# Requirement already satisfied: cachetools>=5.5.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from dspy>=3.0.3->dspy-ai==3.0.3->-r requirements.txt (line 1)) (6.2.0)
# Requirement already satisfied: cloudpickle>=3.0.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from dspy>=3.0.3->dspy-ai==3.0.3->-r requirements.txt (line 1)) (3.1.1)
# Requirement already satisfied: gepa==0.0.7 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from gepa[dspy]==0.0.7->dspy>=3.0.3->dspy-ai==3.0.3->-r requirements.txt (line 1)) (0.0.7)
# Requirement already satisfied: httpcore==1.* in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from httpx>=0.27.2->crawl4ai==0.7.4->-r requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.2->crawl4ai==0.7.4->-r requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from httpx[http2]>=0.27.2->crawl4ai==0.7.4->-r requirements.txt (line 2)) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.27.2->crawl4ai==0.7.4->-r requirements.txt (line 2)) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.27.2->crawl4ai==0.7.4->-r requirements.txt (line 2)) (4.1.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyter-core>=4.7->nbconvert[webpdf]->-r requirements.txt (line 5)) (4.4.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain_text_splitters==0.3.11->-r requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain_text_splitters==0.3.11->-r requirements.txt (line 3)) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from pydantic>=2.10->crawl4ai==0.7.4->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from pydantic>=2.10->crawl4ai==0.7.4->-r requirements.txt (line 2)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from pydantic>=2.10->crawl4ai==0.7.4->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: fastuuid>=0.12.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from litellm>=1.53.1->crawl4ai==0.7.4->-r requirements.txt (line 2)) (0.13.3)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from litellm>=1.53.1->crawl4ai==0.7.4->-r requirements.txt (line 2)) (8.7.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from litellm>=1.53.1->crawl4ai==0.7.4->-r requirements.txt (line 2)) (4.25.1)
# Requirement already satisfied: pondpond<2.0.0,>=1.4.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from litellm>=1.53.1->crawl4ai==0.7.4->-r requirements.txt (line 2)) (1.4.1)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from litellm>=1.53.1->crawl4ai==0.7.4->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: tokenizers in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from litellm>=1.53.1->crawl4ai==0.7.4->-r requirements.txt (line 2)) (0.22.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.53.1->crawl4ai==0.7.4->-r requirements.txt (line 2)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.53.1->crawl4ai==0.7.4->-r requirements.txt (line 2)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.53.1->crawl4ai==0.7.4->-r requirements.txt (line 2)) (0.27.1)
# Requirement already satisfied: madoka>=0.7.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from pondpond<2.0.0,>=1.4.1->litellm>=1.53.1->crawl4ai==0.7.4->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: zipp>=3.20 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from importlib-metadata>=6.8.0->litellm>=1.53.1->crawl4ai==0.7.4->-r requirements.txt (line 2)) (3.23.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from nbclient>=0.5.0->nbconvert[webpdf]->-r requirements.txt (line 5)) (8.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert[webpdf]->-r requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert[webpdf]->-r requirements.txt (line 5)) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert[webpdf]->-r requirements.txt (line 5)) (6.5.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from nbformat>=5.7->nbconvert[webpdf]->-r requirements.txt (line 5)) (2.21.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from openai>=0.28.1->dspy>=3.0.3->dspy-ai==3.0.3->-r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from openai>=0.28.1->dspy>=3.0.3->dspy-ai==3.0.3->-r requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: alembic>=1.5.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from optuna>=3.4.0->dspy>=3.0.3->dspy-ai==3.0.3->-r requirements.txt (line 1)) (1.16.5)
# Requirement already satisfied: colorlog in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from optuna>=3.4.0->dspy>=3.0.3->dspy-ai==3.0.3->-r requirements.txt (line 1)) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from optuna>=3.4.0->dspy>=3.0.3->dspy-ai==3.0.3->-r requirements.txt (line 1)) (2.0.43)
# Requirement already satisfied: Mako in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from alembic>=1.5.0->optuna>=3.4.0->dspy>=3.0.3->dspy-ai==3.0.3->-r requirements.txt (line 1)) (1.3.10)
# Requirement already satisfied: pyee<14,>=13 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from patchright>=1.49.0->crawl4ai==0.7.4->-r requirements.txt (line 2)) (13.0.0)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from patchright>=1.49.0->crawl4ai==0.7.4->-r requirements.txt (line 2)) (3.2.4)
# Requirement already satisfied: cryptography<47,>=45.0.7 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from pyOpenSSL>=24.3.0->crawl4ai==0.7.4->-r requirements.txt (line 2)) (46.0.1)
# Requirement already satisfied: cffi>=2.0.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from cryptography<47,>=45.0.7->pyOpenSSL>=24.3.0->crawl4ai==0.7.4->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: pycparser in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography<47,>=45.0.7->pyOpenSSL>=24.3.0->crawl4ai==0.7.4->-r requirements.txt (line 2)) (2.23)
# Requirement already satisfied: six>=1.5 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert[webpdf]->-r requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from rich>=13.9.4->crawl4ai==0.7.4->-r requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->crawl4ai==0.7.4->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: fake-http-header<0.4.0,>=0.3.5 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from tf-playwright-stealth>=1.1.0->crawl4ai==0.7.4->-r requirements.txt (line 2)) (0.3.5)
# Requirement already satisfied: appnope>=0.1.2 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 4)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 4)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 4)) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 4)) (9.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 4)) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: decorator in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r requirements.txt (line 4)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r requirements.txt (line 4)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r requirements.txt (line 4)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r requirements.txt (line 4)) (3.0.52)
# Requirement already satisfied: stack_data in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r requirements.txt (line 4)) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r requirements.txt (line 4)) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r requirements.txt (line 4)) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from ipywidgets->jupyter==1.0.0->-r requirements.txt (line 4)) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from ipywidgets->jupyter==1.0.0->-r requirements.txt (line 4)) (3.0.15)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (2.27.3)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.5 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (4.4.8)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (0.2.4)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyterlab<4.5,>=4.4.5->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (2.0.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyterlab<4.5,>=4.4.5->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (2.3.0)
# Requirement already satisfied: setuptools>=41.1.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyterlab<4.5,>=4.4.5->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (78.1.1)
# Requirement already satisfied: babel>=2.10 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (25.1.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (3.3.0)
# Requirement already satisfied: rfc3339-validator in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (0.1.1)
# Requirement already satisfied: fqdn in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (1.5.1)
# Requirement already satisfied: isoduration in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (20.11.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: uri-template in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (24.11.1)
# Requirement already satisfied: arrow>=0.15.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 4)) (2.9.0.20250822)
# Requirement already satisfied: qtpy>=2.4.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from qtconsole->jupyter==1.0.0->-r requirements.txt (line 4)) (2.4.3)
# Requirement already satisfied: executing>=1.2.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r requirements.txt (line 4)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r requirements.txt (line 4)) (0.2.3)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from tokenizers->litellm>=1.53.1->crawl4ai==0.7.4->-r requirements.txt (line 2)) (0.35.1)
# Requirement already satisfied: filelock in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.53.1->crawl4ai==0.7.4->-r requirements.txt (line 2)) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.53.1->crawl4ai==0.7.4->-r requirements.txt (line 2)) (2025.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.53.1->crawl4ai==0.7.4->-r requirements.txt (line 2)) (1.1.10)

# %%
# set the disease of interest


TOPIC = "Informative and Accurate Entry of Duchenne Muscular Dystrophy, describing the rare disease, its symptoms and suspected causes, and potential treatments or current efforts to find treatements."

# %%
# configurations, be sure to load appropriate 
# 1.) SERPER_API_KEY
# 2.) LITELLM_API_KEY
# 3.) LITELLM_API_BASE
# :D

import json
import os
from typing import List, Tuple

import dspy
import httpx
from dotenv import load_dotenv
from tqdm import tqdm

from src.dataclass import RetrievedDocument, LiteratureSearchAgentResponse, LiteratureSearchAgentRequest
from src.encoder import Encoder
from src.literature_search import LiteratureSearchAgent
from src.lm import init_lm, LanguageModelProviderConfig, LanguageModelProvider, LiteLLMServerConfig
from src.retriever_agent.serper_rm import SerperRM
from src.rag import RagAgent
from src.dataclass import RagResponse, RagRequest

load_dotenv()
# Out:
# True

# %%
## Sanity check :D
load_dotenv()

test_lm_config = LanguageModelProviderConfig(
      provider=LanguageModelProvider.LANGUAGE_MODEL_PROVIDER_LITELLM_SERVER,
      model_name="gpt-4.1-mini",
      temperature=0.0,
      max_tokens=10,
      litellm_server_config=LiteLLMServerConfig(api_key=os.getenv("LITELLM_API_KEY"), api_base=os.getenv("LITELLM_API_BASE"))
  )
test_lm = init_lm(test_lm_config)
print(test_lm("say 'Hello!' as is")[0]) # Expect to see "Hello!" or something similar
# Out:
# Hello!

# %%
encoder = Encoder(model_name="text-embedding-3-small", **{"api_key": os.getenv("LITELLM_API_KEY"), "api_base": os.getenv("LITELLM_API_BASE")})
embedding = await encoder.aencode("hello")
assert len(embedding[0]) == 1536
print(f"✅ encoder is working")
# Out:
# ✅ encoder is working

# %%
# retriever check



load_dotenv()

serper_retriever = SerperRM(api_key=os.getenv("SERPER_API_KEY"), encoder=encoder)
retrieved_document: RetrievedDocument = await serper_retriever.aretrieve("rare diseases and orphan disease information")
assert len(retrieved_document) > 0
print(f"✅ retriever is working")
print(f"example output")
print(json.dumps(retrieved_document[0].to_dict(), indent=2))
# Out:
# [FETCH]... ↓ https://rarediseases.org/                                                                            |
# ✓ | ⏱: 2.36s
# [SCRAPE].. ◆ https://rarediseases.org/                                                                            |
# ✓ | ⏱: 0.18s
# [COMPLETE] ● https://rarediseases.org/                                                                            |
# ✓ | ⏱: 2.57s
# [FETCH]... ↓ https://rarediseases.org/rare-diseases/                                                              |
# ✓ | ⏱: 3.38s
# [SCRAPE].. ◆ https://rarediseases.org/rare-diseases/                                                              |
# ✓ | ⏱: 0.02s
# [COMPLETE] ● https://rarediseases.org/rare-diseases/                                                              |
# ✓ | ⏱: 3.42s
# [FETCH]... ↓ https://en.wikipedia.org/wiki/Rare_disease                                                           |
# ✓ | ⏱: 3.58s
# [SCRAPE].. ◆ https://en.wikipedia.org/wiki/Rare_disease                                                           |
# ✓ | ⏱: 0.34s
# [COMPLETE] ● https://en.wikipedia.org/wiki/Rare_disease                                                           |
# ✓ | ⏱: 3.93s
# [FETCH]... ↓ https://ojrd.biomedcentral.com/                                                                      |
# ✓ | ⏱: 4.05s
# [SCRAPE].. ◆ https://ojrd.biomedcentral.com/                                                                      |
# ✓ | ⏱: 0.14s
# [COMPLETE] ● https://ojrd.biomedcentral.com/                                                                      |
# ✓ | ⏱: 4.19s
# [FETCH]... ↓ https://rarediseases.info.nih.gov/                                                                   |
# ✓ | ⏱: 4.21s
# [SCRAPE].. ◆ https://rarediseases.info.nih.gov/                                                                   |
# ✓ | ⏱: 0.04s
# [COMPLETE] ● https://rarediseases.info.nih.gov/                                                                   |
# ✓ | ⏱: 4.25s
# [FETCH]... ↓ https://pmc.ncbi.nlm.nih.gov/articles/PMC1502161/                                                    |
# ✓ | ⏱: 4.27s
# [SCRAPE].. ◆ https://pmc.ncbi.nlm.nih.gov/articles/PMC1502161/                                                    |
# ✓ | ⏱: 0.05s
# [COMPLETE] ● https://pmc.ncbi.nlm.nih.gov/articles/PMC1502161/                                                    |
# ✓ | ⏱: 4.33s
# [FETCH]... ↓ https://www.fda.gov/patients/rare-diseases-fda                                                       |
# ✓ | ⏱: 4.34s
# [SCRAPE].. ◆ https://www.fda.gov/patients/rare-diseases-fda                                                       |
# ✓ | ⏱: 0.06s
# [COMPLETE] ● https://www.fda.gov/patients/rare-diseases-fda                                                       |
# ✓ | ⏱: 4.40s
# [FETCH]... ↓ https://www.orpha.net/                                                                               |
# ✓ | ⏱: 4.61s
# [SCRAPE].. ◆ https://www.orpha.net/                                                                               |
# ✓ | ⏱: 0.04s
# [COMPLETE] ● https://www.orpha.net/                                                                               |
# ✓ | ⏱: 4.65s
# [FETCH]... ↓ https://www.ncsl.org/health/rare-and-orphan-diseases                                                 |
# ✓ | ⏱: 5.44s
# [SCRAPE].. ◆ https://www.ncsl.org/health/rare-and-orphan-diseases                                                 |
# ✓ | ⏱: 0.02s
# [COMPLETE] ● https://www.ncsl.org/health/rare-and-orphan-diseases                                                 |
# ✓ | ⏱: 5.47s
# ✅ retriever is working
# example output
# {
#   "url": "https://www.orpha.net/",
#   "excerpts": [
#     "Orphanet is a unique resource, gathering and improving knowledge on rare diseases so as to improve the diagnosis, care and treatment of patients with rare diseases. Orphanet aims to provide high-quality information on rare diseases, and ensure equal access to knowledge for all stakeholders. Orphanet also maintains the Orphanet rare disease nomenclature (ORPHAcode), essential in improving the visibility of rare diseases in health and research information systems. \nOrphanet was established in France by the INSERM (French National Institute for Health and Medical Research) in 1997. This initiative became a European endeavour from 2000, supported by grants from the European Commission: Orphanet has gradually grown to a Consortium of 40 countries, within Europe and across the globe. \nOrphaNews is a freely available, twice-monthly electronic newsletter for the rare disease community, presenting an overview of scientific and political news about rare diseases and orphan drugs. \nThe Orphadata platform provides the scientific community with comprehensive, high-quality datasets related to rare diseases and orphan drugs, in a reusable and computable format. \nThe Orphanet Rare Disease Ontology (ORDO) is a structured vocabulary for rare diseases derived from the Orphanet database, capturing relationships between diseases, genes and other relevant features. ORDO provides integrated, re-usable data for computational analysis. \nOrphanet works with the rare disease community in order to provide its users with quality, up-to-date information on rare diseases and to improve its services.\nContribute to Orphanet scientific data and give your feedback using our interactive community-driven curation platform for experts.\nImprove the visibility of your activities related to rare diseases by registering them with Orphanet.\nPartner with Orphanet and support us in our mission to improve knowledge and information on rare diseases.",
#     "Orphanet produces a series of highly-downloaded reports showcasing aggregated data covering topics relevant to all rare diseases. This series includes a list of rare diseases, reports on epidemiological data, list of orphan drugs, rare disease registries in Europe, list of research infrastructures useful to rare diseases in Europe, Orphanet's annual activity report, and Orphanet's satisfaction surveys, as well as the list of experts having contributed to data in Orphanet."
#   ],
#   "title": "Orphanet",
#   "timestamp": null,
#   "reason_for_retrieval": "rare diseases and orphan disease information",
#   "document_type": 1,
#   "metadata": null
# }

# %% [markdown]
# ### Objective
# Evaluate the complete Retrieval-Augmented Generation pipeline to understand information flow through the following stages:
#
# ```
# Query → Internet Search → Content Extraction → Document Chunking → Semantic Reranking → Answer Generation
# ```
#
# ---

# %%
# configure the language model for RAG agent
rag_lm_config = LanguageModelProviderConfig(
    provider=LanguageModelProvider.LANGUAGE_MODEL_PROVIDER_LITELLM_SERVER,
    model_name="gpt-4.1-mini",
    temperature=1.0,
    max_tokens=10000,
    litellm_server_config=LiteLLMServerConfig(api_key=os.getenv("LITELLM_API_KEY"), api_base=os.getenv("LITELLM_API_BASE"))
)
rag_lm = init_lm(rag_lm_config)

# initialize the RAG agent
rag = RagAgent(retriever=serper_retriever, rag_lm=rag_lm)

# forward the request to the RAG agent
rag_response: RagResponse = await rag.aforward(RagRequest(question="Provide a informative entry about Duchenne Muscular Dystrophy.", max_retriever_calls=1))

# make output directory if it doesn't exist
os.makedirs("output", exist_ok=True)

# save the response to a file
with open("output/action_item_3_rag_response.json", "w") as f:
    json.dump(rag_response.to_dict(), f, indent=2)

print(f"✅ Result saved to output/action_item_3_rag_response.json")
# Out:
# [FETCH]... ↓ https://rarediseases.org/rare-diseases/duchenne-muscular-dystrophy/                                  |
# ✓ | ⏱: 3.69s
# [SCRAPE].. ◆ https://rarediseases.org/rare-diseases/duchenne-muscular-dystrophy/                                  |
# ✓ | ⏱: 0.18s
# [COMPLETE] ● https://rarediseases.org/rare-diseases/duchenne-muscular-dystrophy/                                  |
# ✓ | ⏱: 3.94s
# [FETCH]... ↓ https://en.wikipedia.org/wiki/Duchenne_muscular_dystrophy                                            |
# ✓ | ⏱: 4.18s
# [SCRAPE].. ◆ https://en.wikipedia.org/wiki/Duchenne_muscular_dystrophy                                            |
# ✓ | ⏱: 0.86s
# [SCRAPE].. ◆ https://www.parentprojectmd.org/about-duchenne/what-is-duchenne/                                     |
# ✓ | ⏱: 0.07s
# [COMPLETE] ● https://www.parentprojectmd.org/about-duchenne/what-is-duchenne/                                     |
# ✓ | ⏱: 6.73s
# ✅ Result saved to output/action_item_3_rag_response.json

# %% [markdown]
# ### Autonomous Literature Search Evaluation
#
#
# ---

# %%
literature_search_planning_lm = init_lm(LanguageModelProviderConfig(
    provider=LanguageModelProvider.LANGUAGE_MODEL_PROVIDER_LITELLM_SERVER,
    model_name="gpt-4.1", # NOTE: planning invovles intelligence, so we use a more powerful model.
    temperature=1.0,
    max_tokens=10000,
    litellm_server_config=LiteLLMServerConfig(api_key=os.getenv("LITELLM_API_KEY"), api_base=os.getenv("LITELLM_API_BASE"))
))

answer_synthesis_lm = init_lm(LanguageModelProviderConfig(
    provider=LanguageModelProvider.LANGUAGE_MODEL_PROVIDER_LITELLM_SERVER,
    model_name="gpt-5-mini", # NOTE: synthesis does not require high intelligence, but requires minimal hallucination. GPT-5-mini is a good balance.
    temperature=1.0,
    max_tokens=20000,
    litellm_server_config=LiteLLMServerConfig(api_key=os.getenv("LITELLM_API_KEY"), api_base=os.getenv("LITELLM_API_BASE"))
))

# initialize the literature search agent
literature_search_agent = LiteratureSearchAgent(rag_agent=rag, literature_search_lm=literature_search_planning_lm, answer_synthesis_lm=answer_synthesis_lm)

# run the literature search agent
literature_search_response: LiteratureSearchAgentResponse = await literature_search_agent.aforward(LiteratureSearchAgentRequest(topic=TOPIC))

# save the response to a file
with open("output/action_item_4_literature_search_response.json", "w") as f:
    json.dump(literature_search_response.to_dict(), f, indent=2)

print(f"✅ Result saved to output/literature_search_response.json")
# Out:
# Starting literature search for topic: Informative and Accurate Entry of Duchenne Muscular Dystrophy, describing the rare disease, its symptoms and suspected causes, and potential treatments or current efforts to find treatements.
# Completeness check start.
# Completeness check: False, reasoning: Major pillars of the topic—definition, symptoms, and causes—have not been addressed yet, signifying substantial gaps that must be filled before the survey can be considered comprehensive.
# Generated 3 next questions for exploration
# Executing 3
# RAG call start. Question: What is Duchenne Muscular Dystrophy, and how is it classified as a rare disease?. Question context: Foundational description and classification are core to the survey, allowing readers to understand what the disease is and why it is considered rare; this element is missing and essential for contextualizing subsequent details.
# RAG call start. Question: What are the primary symptoms of Duchenne Muscular Dystrophy and how do they typically present?. Question context: Symptoms are a major subtopic directly requested in the survey guideline, and their exploration is necessary for thorough understanding of the disease's impact and progression.
# RAG call start. Question: What are the suspected causes and underlying genetic mechanisms of Duchenne Muscular Dystrophy?. Question context: Understanding the causes, including genetic factors, is strategic for comprehending disease origin and is a mandatory scope per the topic guideline.
# [FETCH]... ↓ https://my.clevelandclinic.org/health/diseases/23538-duchenne-muscular-dystrophy-dmd                 |
# ✓ | ⏱: 24.49s
# [SCRAPE].. ◆ https://my.clevelandclinic.org/health/diseases/23538-duchenne-muscular-dystrophy-dmd                 |
# ✓ | ⏱: 0.21s
unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x119e09ad0>
# [SCRAPE].. ◆ https://pmc.ncbi.nlm.nih.gov/articles/PMC10667703/                                                   |
# ✓ | ⏱: 0.87s
# [COMPLETE] ● https://pmc.ncbi.nlm.nih.gov/articles/PMC10667703/                                                   |
# ✓ | ⏱: 32.74s
# [FETCH]... ↓ https://www.frontiersin.org/journals/physiology/articles/10.3389/fphys.2023.1183101/full             |
# ✓ | ⏱: 37.43s
# [SCRAPE].. ◆ https://www.frontiersin.org/journals/physiology/articles/10.3389/fphys.2023.1183101/full             |
# ✓ | ⏱: 1.38s
# [COMPLETE] ● https://www.frontiersin.org/journals/physiology/articles/10.3389/fphys.2023.1183101/full             |
# ✓ | ⏱: 38.83s
# [FETCH]... ↓ https://www.mda.org/disease/duchenne-muscular-dystrophy                                              |
# ✓ | ⏱: 47.88s
# [SCRAPE].. ◆ https://www.mda.org/disease/duchenne-muscular-dystrophy                                              |
# ✓ | ⏱: 0.13s
# [COMPLETE] ● https://www.mda.org/disease/duchenne-muscular-dystrophy                                              |
# ✓ | ⏱: 48.02s
# [FETCH]... ↓ https://journals.biologists.com/dmm/article/18/7...368762/Understanding-Duchenne-muscular-dystrophy  |
# ✓ | ⏱: 48.37s

# %% [markdown]
# ## Action Item 5: Primary Source Database Exploration
#
# > **Reference:** See **Section 4.2 (ACLED Database & Primary Source Analysis)** in the handout for comprehensive coverage of investigative research methodologies and database exploration strategies.
#
# ### Objective
# Transition from literature synthesis to investigative analysis through systematic exploration of primary source data. This exercise demonstrates capabilities beyond web-accessible information by leveraging structured conflict databases.
#
# **Data Source:** Armed Conflict Location & Event Data Project (ACLED)
# - **Coverage:** Global conflict events with structured metadata
# - **Temporal Scope:** Real-time updates with historical records
# - **Analytical Advantages:** Systematic pattern detection, geographic clustering, temporal trend analysis
#
# ### Step 1: Database Exploration Agent Initialization
#
# ---

# %%
# This dspy signature is used to generate seed questions using writeup from previous literature search to kick start the database exploration. 
class ResearchQuestionGenerator(dspy.Signature):
    """You are conducting research to extract previously unknown insights by exploring and observing information in a database. Generate research questions that an investigator will be interested in. The questions will be used to generate search queries in the database to help answer them. The questions should be self-contained, meaning they must include any specific years, months, locations, or other details instead of references that require the reader to know additional context. All questions must be related to the research goal and topic. Investigate any correlations as you see fit. The questions should be completely independent of each other - if you believe some questions need to be answered first before others can be meaningful, only generate those foundational questions and not others that depend on the answers to the first questions. You do not need to generate the maximum number of questions if you believe fewer questions would be better for the research goals."""
    
    topic: str = dspy.InputField(desc="The research goal or topic being investigated")
    db_description: str = dspy.InputField(desc="Description of the available database including its structure, contents, and capabilities")
    max_questions: int = dspy.InputField(desc="Maximum number of questions to generate - you may generate fewer if appropriate")
    previous_insights: str = dspy.InputField(desc="Previous insights from the database")
    
    questions: List[str] = dspy.OutputField(desc="List of independent, self-contained research questions that will extract previously unknown insights related to the topic from the database")

generate_exploration_questions = dspy.Predict(ResearchQuestionGenerator)

# %%
# research question generation
database_exploration_lm_config = LanguageModelProviderConfig(
    provider=LanguageModelProvider.LANGUAGE_MODEL_PROVIDER_LITELLM_SERVER,
    model_name="gpt-4.1", # database exploration planning requires high intelligence, so we use a more powerful model.
    temperature=1.0,
    max_tokens=10000,
    litellm_server_config=LiteLLMServerConfig(api_key=os.getenv("LITELLM_API_KEY"), api_base=os.getenv("LITELLM_API_BASE"))
)
database_exploration_lm = init_lm(database_exploration_lm_config)

# load the literature search response
assert os.path.exists("output/action_item_4_literature_search_response.json"), "Please run the literature search first"
literature_search_response = LiteratureSearchAgentResponse.from_dict(json.load(open("output/action_item_4_literature_search_response.json")))

with dspy.context(lm=database_exploration_lm):
    seed_questions = (await generate_exploration_questions.aforward(
        topic=TOPIC, 
        db_description=ACLED_DB_DESCRIPTION, 
        max_questions=4, 
        previous_insights=literature_search_response.writeup
    )).questions

seed_questions_formatted = "\n\t- ".join(seed_questions)
print(f"✅ Seed questions generated. Seed questions:\n\t- {seed_questions_formatted}")
# Out:
# ✅ Seed questions generated. Seed questions:
# 	- How have the frequency, intensity, and geographic distribution of different types of military operations (e.g., offensive assaults, defensive operations, drone strikes, cross-border raids) by both Russian and Ukrainian forces changed from 2022 to early 2025, and what patterns emerge when comparing phases of the conflict?
# 	- What correlations exist between periods of significant Western/NATO military aid deliveries to Ukraine and subsequent shifts in Ukrainian military operational tactics, such as increased use of precision strikes, adoption of defense-in-depth, or expanded use of unmanned systems?
# 	- Is there measurable evidence that the introduction and increased usage of AI-enabled or autonomous systems (such as drones or unmanned surface vessels) by either Russia or Ukraine resulted in statistically significant changes in battlefield outcomes, such as territory gained/lost, casualty rates, or disruption of enemy operations between 2023 and early 2025?
# 	- In regions where Russian and Ukrainian forces conducted the heaviest fighting (e.g., Donbas, Kherson, Avdiivka), how did the composition and structure of local military engagements (in terms of force size, technology used, frequency of artillery vs. infantry action) evolve over the course of the conflict, and what future trends does this suggest for similar conflicts?

# %% [markdown]
# ## DSPy Implementation for Automated Thesis Generation
#
# > **Reference:** See **Section 4.3 (DSPy Framework)** in the handout.
#
# ---

# %%
class ThesisGenerator(dspy.Signature):
    """
    You are GENERATING exactly FIVE (5) INVESTIGATIVE thesis statements that synthesize 
    THE ORIGINAL RESEARCH TOPIC, STRUCTURED DATABASE INSIGHTS, and LITERATURE REVIEW HIGHLIGHTS AND GAPS.

    THe requrements for each thesis are as follows: Specific! Names teh actors and actions, avoids vagueness. Evidence based, CITE at least one concrete data point OR pattern from the 
    database inputs OR precise claims from literature, Analytcically defensable, AND goes over societal impact EXPLICTLY must be CONCISE and MEMORABLE.

    

    
    """
    original_topic: str = dspy.InputField(
        desc="The initial research topic that was explored"
    ) 
    
    # db_figures: str = dspy.InputField(
    #     desc="Responses from database exploration"
   
    # )

    
    # ===============================================
    # additional input fields here
    # Hint1: how to pass insights from database exploration agent to the thesis generator?
    # Hint2: will directly concatenate question and answers from database exploration agent work? Do we need any formatting?
    # ===============================================
    
    # Should only have one output field as defined below. Do not change the name of the output field.
    proposed_theses: List[str] = dspy.OutputField(
        desc="""A python list of exactly five distinct, concise thesis. each is specific 
        names actors and cites a conrete pattern or figure when critical. (specific, evidence-based, and analytically defensible)"""
    )

thesis_generator = dspy.Predict(ThesisGenerator)
thesis_generator_lm = init_lm(LanguageModelProviderConfig(
    provider=LanguageModelProvider.LANGUAGE_MODEL_PROVIDER_LITELLM_SERVER,
    model_name="gpt-4.1", # NOTE: thesis generation requires high intelligence, so we use a more powerful model.
    temperature=1.0,
    max_tokens=10000,
    litellm_server_config=LiteLLMServerConfig(api_key=os.getenv("LITELLM_API_KEY"), api_base=os.getenv("LITELLM_API_BASE"))
))

# %%
database_exploration_rag_responses = []
with open("data/action_item_5_database_exploration_precomputed.json", "r") as f:
    database_exploration_precomputed = json.load(f)
    database_exploration_rag_responses = database_exploration_precomputed.get("rag_service_responses", [])


with dspy.context(lm=thesis_generator_lm):
    generated_theses = (await thesis_generator.aforward(
        original_topic=TOPIC,
        # ===============================================
        # other input fields here
        # ===============================================
        # db_figures = database_exploration_rag_responses,
        
    )).proposed_theses

formatted_generated_theses = "\n\t-".join(generated_theses)
print(f"generated_theses:\n\t- {formatted_generated_theses}")

with open("output/action_item_6_generated_theses.json", "w") as f:
    json.dump({
        "generated_theses": generated_theses
    }, f, indent=2)
print(f"✅ Result saved to output/action_item_6_generated_theses.json")

print(f"\n\nTake a look at the output format and skim through the content. Are you satisfied with the results? Will audience be interested in your proposed theses? With doubt, it's always a good idea to revise the prompt and try again.")
if len(generated_theses) != 5:
    raise ValueError(f"❌ Please generate exactly 5 proposed theses but found {len(generated_theses)}.")
# Out:
# generated_theses:
# 	- Genetic mutations in the DMD gene are confirmed as the singular cause of Duchenne Muscular Dystrophy, as evidenced by over 95% of diagnosed cases showing deletions or duplications in this locus, underscoring the necessity for molecular diagnostic protocols in clinical settings (Emery, 2023).
# 	-Progressive muscle wasting and cardiac involvement, observed consistently in longitudinal studies of DMD patients (Mendell et al., 2016), directly correlate with reduced life expectancy—highlighting an urgent societal need for expanded cardiopulmonary care in pediatric neuromuscular clinics.
# 	-Despite promising results in early-phase exon-skipping trials (e.g., eteplirsen leading to increased dystrophin production in 30% of treated subjects), significant barriers remain in translating genetic therapies for DMD into widely accessible treatments, with cost and equitable access representing the main public health challenge (FDA, 2021).
# 	-Steroid treatments such as prednisone and deflazacort have extended ambulatory function by an average of 2.5 years in DMD patients, as shown in multicenter meta-analyses, but their use also introduces a critical trade-off: worsened metabolic side effects and quality of life for vulnerable populations (Birnkrant et al., 2018).
# 	-Community-driven awareness campaigns and advocacy by parent organizations, as mapped by a 300% increase in funding for DMD research between 2010 and 2022, have directly influenced public policy and industry drug development priorities—demonstrating the powerful societal impact of coordinated patient action (Parent Project Muscular Dystrophy, 2023).
# ✅ Result saved to output/action_item_6_generated_theses.json
#
#
# Take a look at the output format and skim through the content. Are you satisfied with the results? Will audience be interested in your proposed theses? With doubt, it's always a good idea to revise the prompt and try again.

# %% [markdown]
# # database_exploration_rag_responses = []
# with open("data/action_item_5_database_exploration_precomputed.json", "r") as f:
#     database_exploration_precomputed = json.load(f)
#     database_exploration_rag_responses = ... # TODO: add the rag responses to the list
#
# with dspy.context(lm=thesis_generator_lm):
#     generated_theses = (await thesis_generator.aforward(
#         original_topic=TOPIC,
#         # ===============================================
#         # other input fields here
#         # ===============================================
#     )).proposed_theses
#
# formatted_generated_theses = "\n\t-".join(generated_theses)
# print(f"generated_theses:\n\t- {formatted_generated_theses}")
#
# with open("output/action_item_6_generated_theses.json", "w") as f:
#     json.dump({
#         "generated_theses": generated_theses
#     }, f, indent=2)
# print(f"✅ Result saved to output/action_item_6_generated_theses.json")
#
# print(f"\n\nTake a look at the output format and skim through the content. Are you satisfied with the results? Will audience be interested in your proposed theses? With doubt, it's always a good idea to revise the prompt and try again.")
# if len(generated_theses) != 5:
#     raise ValueError(f"❌ Please generate exactly 5 proposed theses but found {len(generated_theses)}.")

# %% [markdown]
# **Extra human-in-the-loop step**
# Manually review all generated thesis and hand pick the best 2

# %%
# Review the generated these and hand pick the best 2 theses.
selected_theses = [
    "Genetic mutations in the DMD gene are confirmed as the singular cause of Duchenne Muscular Dystrophy, as evidenced by over 95% of diagnosed cases showing deletions or duplications in this locus, underscoring the necessity for molecular diagnostic protocols in clinical settings (Emery, 2023).",
    "Progressive muscle wasting and cardiac involvement, observed consistently in longitudinal studies of DMD patients (Mendell et al., 2016), directly correlate with reduced life expectancy—highlighting an urgent societal need for expanded cardiopulmonary care in pediatric neuromuscular clinics."
]

assert len(selected_theses) == 2, f"❌ Please select exactly 2 theses but found {len(selected_theses)}."
with open("output/action_item_6_selected_theses.json", "w") as f:
    json.dump({
        "selected_theses": selected_theses
    }, f, indent=2)
print(f"✅ Result saved to output/action_item_6_selected_theses.json")
# Out:
# ✅ Result saved to output/action_item_6_selected_theses.json

# %% [markdown]
# ## Action Item 7: Automated Investigative Report Synthesis
#
# > **Reference:** See **Section 4.4 (Synthesis & Report Composition)** in the handout for comprehensive methodology on evidence synthesis and investigative narrative construction.
#
# ### Objective
# Synthesize your research findings into a comprehensive investigative report using automated DSPy-based processing pipelines that demonstrate advanced research capabilities beyond traditional literature synthesis.
#
# ### Generated Report Structure:
# 1. **Executive Summary:** A concise overview of your key findings and their significance
# 2. **Sections:** Use `#` for primary sections; Use `##` for subsections that organize detailed analysis; etc.
# 3. **Inline Citations:** Use numbered references in square brackets (e.g., `[1]`, `[2]`, `[3]`)
# 4. **Bibliography:** Conclude with a reference section where each line follows the format: `[index]. URL or source description`
#
# ### Implementation Process:
#
# **Step 1: Thesis-Specific Literature Search**
#
# Using your three generated theses from Action Item 6, conduct targeted literature searches for each thesis. Implement a `LiteratureSearchAgentRequest` with the `guideline` parameter to focus searches on supporting evidence for each specific thesis. Set `with_synthesis=False` to collect raw `rag_responses` for later processing.
#
# **Step 2: Key Insight Identification**
#
# Implement a `KeyInsightIdentifier` DSPy signature to automatically extract the most important insight from each RAG response. This reduces noise and focuses on essential information for report composition. The key insight should be a concise, one-sentence summary capturing the most relevant information for each question-answer pair.
#
# **Step 3: Report Structure and Guideline Generation**
#
# Create a `FinalWritingGuidelineProposal` DSPy signature that uses the collected key insights to:
# - Generate a unified report thesis that synthesizes your investigative findings
# - Propose a structured writing guideline in bullet-point format outlining key sections and content organization
# - Ensure logical flow from background through specific discoveries to implications
#
# **Step 4: Automated Report Synthesis**
#
# Implement a `FinalReportSynthesizer` DSPy signature that combines the report thesis, writing guidelines, and all collected evidence into a coherent investigative report. The synthesizer should:
# - Merge relevant information into logically coherent narrative sections
# - Preserve all original citations exactly as provided
# - Eliminate redundancy while maintaining completeness
# - Create smooth transitions between thematic sections
# - Constrain content to provided information without external speculation
#
# ### Quality Standards:
#
# Your final report should demonstrate investigative depth by presenting original analytical insights not readily available in existing literature, comprehensive coverage through automated integration of evidence from multiple search iterations, logical organization with clear progression from initial questions to final conclusions, and proper attribution through systematic citation preservation.
#
# The completed report should read as a coherent investigative piece rather than a collection of separate research summaries, showcasing the power of automated synthesis in building compelling investigative narratives from distributed evidence sources.
#
# ---

# %%
## After you have generated 3 theses, we'll generate another round of literature search to support your theses. 
rag_responses = []

for idx, thesis in enumerate(selected_theses, 1):
    # ===============================================
    # TODO: generate literature search request. Take a look at definition of LiteratureSearchAgentRequest
    # Hint: previously we only use the field `topic` and leave other fields as default. Now we need to make use of the field `guideline`. Take a look at the source code to understand how the guideline is used.
    # Hint 2: we disable the synthesis step by setting `with_synthesis=False` as we only need the rag responses.
    # ===============================================
    literature_search_response: LiteratureSearchAgentResponse = await literature_search_agent.aforward(LiteratureSearchAgentRequest(topic=thesis, guideline=(
            "Objective: retrieve high-quality, citable biomedical/clinical sources that DIRECTLY SUPPORT, CLARIFY, "
            "OR CHALLENGE the thesis about this rare/orphan disease.\n"
            f"Target thesis: {thesis}\n\n"
            "Priority sources (in order):\n"
            "- Authoritative rare disease resources (NIH/NCATS GARD, Orphanet, GeneReviews)\n"
            "- Peer-reviewed review articles and consensus/guideline statements on this disease or its gene/pathway\n"
            "- PubMed-indexed clinical cohort/longitudinal studies (epidemiology, natural history, genotype–phenotype)\n"
            "- Regulatory or label information for disease-specific therapies (FDA, EMA), when relevant\n"
            "- ClinicalTrials.gov / trial registry entries for current investigational approaches\n\n"
            "Extraction focus:\n"
            "- Disease definition and classification (is it clearly the same condition as in the thesis?)\n"
            "- Genetics/etiology: gene, variant classes, inheritance, percentage of cases explained\n"
            "- Phenotype: core signs/symptoms, age of onset, organ systems involved, severity range\n"
            "- Diagnosis: recommended tests, molecular confirmation rates, differential diagnoses\n"
            "- Management/therapy: standard-of-care, disease-modifying options, trialed therapies, reported outcomes\n"
            "- Prognosis/natural history: survival, loss of function milestones, complications\n"
            "- Explicit statements of LIMITED or INSUFFICIENT evidence (these are important for our ‘What Is Not Known’ section)\n\n"
            "Style/constraints:\n"
            "- Prefer up-to-date (last 5–10 years) reviews/guidelines when available.\n"
            "- Exclude non-reviewed blogs, unsourced social posts, general news outlets.\n"
            "- If only case reports exist, return them and clearly mark as low-N evidence.\n"
            "- Return raw RAG items only; DO NOT synthesize.\n"
        ), with_synthesis=False))
    
    
    with open(f"output/action_item_7_literature_search_response_{idx}.json", "w") as f:
        json.dump(literature_search_response.to_dict(), f, indent=2)
    print(f"✅ Result saved to output/action_item_7_literature_search_response_{idx}.json")

    rag_responses.extend(literature_search_response.rag_responses) # TODO: add the rag response to the list
# Out:
# Starting literature search for topic: Genetic mutations in the DMD gene are confirmed as the singular cause of Duchenne Muscular Dystrophy, as evidenced by over 95% of diagnosed cases showing deletions or duplications in this locus, underscoring the necessity for molecular diagnostic protocols in clinical settings (Emery, 2023).
# Completeness check start.
# Completeness check: False, reasoning: No exploration tasks have been completed, so all critical components—especially the genetic etiology, possible exceptions, and evidence for diagnostic protocols—must be addressed with direct, recent, and authoritative sources to comprehensively survey the thesis.
# Generated 3 next questions for exploration
# Executing 3
# RAG call start. Question: What do recent authoritative resources (GeneReviews, Orphanet, NIH GARD) state about the genetic basis, gene involved, and variant types responsible for Duchenne Muscular Dystrophy? Please extract statements on etiology, percentage breakdown of mutation types, and inheritance patterns.. Question context: Directly addresses the main thesis by establishing if current top-tier rare disease sources confirm DMD as caused singularly by mutations in the DMD gene, with breakdown of variant types, as well as patterns of inheritance.
# RAG call start. Question: Are there recent comprehensive peer-reviewed review articles or clinical guidelines that report or discuss exceptions or atypical cases of Duchenne Muscular Dystrophy not caused by DMD gene mutations? Extract data or statements relating to rare or alternative etiologies and their frequency.. Question context: Clarifies if the 'singular' cause assertion is supported or contradicted in the high-level literature, ensuring that no major counterexamples are missed per guideline focus.
# RAG call start. Question: What do current molecular diagnostic protocols or recommendations (from guidelines, consensus statements, or clinical laboratory sources) state about their necessity, sensitivity, and utility in confirming clinical diagnoses of Duchenne Muscular Dystrophy?. Question context: Addresses the thesis claim regarding the necessity of molecular diagnosis by targeting up-to-date clinical recommendations and diagnostic sensitivity, which are core requirements in the guideline.
# [FETCH]... ↓ https://www.ninds.nih.gov/sites/default/files/20...e_Working_Group_Recommendations_508_20250530.pdf  |
# ✓ | ⏱: 56.42s
# [SCRAPE].. ◆ https://www.ninds.nih.gov/sites/default/files/20...e_Working_Group_Recommendations_508_20250530.pdf  |
# ✓ | ⏱: 1.78s
# [COMPLETE] ● https://www.ninds.nih.gov/sites/default/files/20...e_Working_Group_Recommendations_508_20250530.pdf  |
# ✓ | ⏱: 66.30s
# [FETCH]... ↓ https://www.ninds.nih.gov/sites/default/files/documents/2005_MDCC_action_plan_508c.pdf               |
# ✓ | ⏱: 67.43s
# [SCRAPE].. ◆ https://www.ninds.nih.gov/sites/default/files/documents/2005_MDCC_action_plan_508c.pdf               |
# ✓ | ⏱: 0.03s
# [COMPLETE] ● https://www.ninds.nih.gov/sites/default/files/documents/2005_MDCC_action_plan_508c.pdf               |
# ✓ | ⏱: 67.56s
# Generated 2 next questions for exploration
# Executing 2
# RAG call start. Question: Extract high-quality, authoritative sources that detail the core clinical phenotype, onset patterns, organ systems affected, and severity spectrum of Duchenne Muscular Dystrophy, specifically focusing on consistency with DMD gene mutation etiology.. Question context: There is currently a gap in sourced, succinct statements and data from biomedical/clinical references clarifying whether the clinical features and progression of DMD consistently match the genetic diagnosis, which is a guideline extraction focus (phenotype) and needed for comprehensive survey coverage.
# RAG call start. Question: Retrieve guideline or longitudinal cohort sources reporting on the prognosis and natural history of Duchenne Muscular Dystrophy, including survival rates, key milestones in disease progression, and most frequent complications.. Question context: No high-quality evidence has yet been extracted specifying prognosis and the natural course of DMD from clinical guidelines or peer-reviewed cohorts, which is mandatory per the guideline for understanding disease burden and outcome in context of molecular diagnosis.
# [FETCH]... ↓ https://omim.org/entry/310200                                                                        |
# ✓ | ⏱: 50.30s
# [SCRAPE].. ◆ https://omim.org/entry/310200                                                                        |
# ✓ | ⏱: 11.36s
# [COMPLETE] ● https://omim.org/entry/310200                                                                        |
# ✓ | ⏱: 63.12s
# [FETCH]... ↓ https://www.frontiersin.org/journals/pediatrics/articles/10.3389/fped.2025.1569505/full              |
# ✓ | ⏱: 63.45s
# [SCRAPE].. ◆ https://www.frontiersin.org/journals/pediatrics/articles/10.3389/fped.2025.1569505/full              |
# ✓ | ⏱: 0.85s
# [COMPLETE] ● https://www.frontiersin.org/journals/pediatrics/articles/10.3389/fped.2025.1569505/full              |
# ✓ | ⏱: 64.35s
# [FETCH]... ↓ https://pmc.ncbi.nlm.nih.gov/articles/PMC6367719/                                                    |
# ✓ | ⏱: 66.04s
# [SCRAPE].. ◆ https://pmc.ncbi.nlm.nih.gov/articles/PMC6367719/                                                    |
# ✓ | ⏱: 2.33s
# [COMPLETE] ● https://pmc.ncbi.nlm.nih.gov/articles/PMC6367719/                                                    |
# ✓ | ⏱: 68.40s
# [FETCH]... ↓ https://www.sciencedirect.com/science/article/abs/pii/S0929693X25001757                              |
# ✓ | ⏱: 67.44s
# [SCRAPE].. ◆ https://www.sciencedirect.com/science/article/abs/pii/S0929693X25001757                              |
# ✓ | ⏱: 0.18s
# [COMPLETE] ● https://www.sciencedirect.com/science/article/abs/pii/S0929693X25001757                              |
# ✓ | ⏱: 67.62s
# [FETCH]... ↓ https://www.researchgate.net/publication/3440789...res_of_families_with_Duchenne_muscular_dystrophy  |
# ✓ | ⏱: 70.34s
# [SCRAPE].. ◆ https://www.researchgate.net/publication/3440789...res_of_families_with_Duchenne_muscular_dystrophy  |
# ✓ | ⏱: 0.02s
# [COMPLETE] ● https://www.researchgate.net/publication/3440789...res_of_families_with_Duchenne_muscular_dystrophy  |
# ✓ | ⏱: 70.39s
# [FETCH]... ↓ https://www.sciencedirect.com/science/article/pii/S2699940425000396                                  |
# ✓ | ⏱: 70.41s
# [SCRAPE].. ◆ https://www.sciencedirect.com/science/article/pii/S2699940425000396                                  |
# ✓ | ⏱: 0.99s
# [FETCH]... ↓ https://jheor.org/post/3123-science-is-rewriting...e-muscular-dystrophy-lifespan-care-must-catch-up  |
# ✓ | ⏱: 93.92s
# [SCRAPE].. ◆ https://jheor.org/post/3123-science-is-rewriting...e-muscular-dystrophy-lifespan-care-must-catch-up  |
# ✓ | ⏱: 0.03s
# [COMPLETE] ● https://jheor.org/post/3123-science-is-rewriting...e-muscular-dystrophy-lifespan-care-must-catch-up  |
# ✓ | ⏱: 93.95s
# [FETCH]... ↓ https://rarediseases.org/rare-diseases/duchenne-muscular-dystrophy/                                  |
# ✓ | ⏱: 93.97s
# [SCRAPE].. ◆ https://rarediseases.org/rare-diseases/duchenne-muscular-dystrophy/                                  |
# ✓ | ⏱: 0.50s
# [COMPLETE] ● https://rarediseases.org/rare-diseases/duchenne-muscular-dystrophy/                                  |
# ✓ | ⏱: 94.47s
# [FETCH]... ↓ https://www.jposna.com/article/S2768-2765(24)00980-5/fulltext                                        |
# ✓ | ⏱: 94.76s
# [SCRAPE].. ◆ https://www.jposna.com/article/S2768-2765(24)00980-5/fulltext                                        |
# ✓ | ⏱: 1.83s
# [COMPLETE] ● https://www.jposna.com/article/S2768-2765(24)00980-5/fulltext                                        |
# ✓ | ⏱: 96.59s
# Completed iteration 10, remaining budget: 5
# Completeness check start.
# Completeness check: True, reasoning: All mandatory guideline extraction areas (etiology, exception frequency, phenotype/genotype correlation, molecular diagnostics, prognosis, and natural history) have been comprehensively and authoritatively addressed with high-quality, citable sources; there are no major gaps left relevant to the thesis or guideline requirements.
# Literature search deemed complete by completeness checker
# Survey completed with 5 responses
# ✅ Result saved to output/action_item_7_literature_search_response_1.json
# Starting literature search for topic: Progressive muscle wasting and cardiac involvement, observed consistently in longitudinal studies of DMD patients (Mendell et al., 2016), directly correlate with reduced life expectancy—highlighting an urgent societal need for expanded cardiopulmonary care in pediatric neuromuscular clinics.
# Completeness check start.
# Completeness check: False, reasoning: No elements of the required scope have yet been explored; foundational disease definitions, clinical guidelines, and direct clinical evidence remain missing and must be established through parallel investigation in key areas prioritized by the guideline.
# Generated 3 next questions for exploration
# Executing 3
# RAG call start. Question: What do authoritative rare disease resources (such as NIH/NCATS GARD, Orphanet, or GeneReviews) state about the definition, classification, and natural history of Duchenne muscular dystrophy (DMD), specifically with respect to progressive muscle wasting and cardiac involvement?. Question context: Answers will establish foundational disease characterization and directly assess alignment with the thesis statement regarding phenotype and organ involvement, fulfilling the priority guideline for authoritative source extraction.
# RAG call start. Question: Which recent (past 5–10 years) peer-reviewed review articles or consensus/guideline statements address cardiopulmonary complications and their impact on prognosis/life expectancy in DMD pediatric populations?. Question context: This question targets clinically actionable insights and citable evidence on the relationship between cardiac issues, muscle wasting, and outcomes—core to the thesis and crucial for guideline-concordant management recommendations.
# RAG call start. Question: What are the key findings from PubMed-indexed clinical cohort or longitudinal studies on genotype–phenotype correlations, loss of function milestones, and survival rates in DMD, particularly concerning cardiac involvement?. Question context: Strategically important for supporting or challenging the thesis, as such studies provide direct data on the progression and prognosis linked to genetic and clinical variables in DMD.
# ✓ | ⏱: 70.27s
# [SCRAPE].. ◆ https://www.clinicaltrialsregister.eu/ctr-search/trial/2022-003126-42/PL                             |
# ✓ | ⏱: 0.19s
# [COMPLETE] ● https://www.clinicaltrialsregister.eu/ctr-search/trial/2022-003126-42/PL                             |
# ✓ | ⏱: 70.46s
# [FETCH]... ↓ https://www.clinicaltrialsarena.com/features/dmd...s-on-building-designs-around-relevant-endpoints/  |
# ✓ | ⏱: 70.49s
# [SCRAPE].. ◆ https://www.clinicaltrialsarena.com/features/dmd...s-on-building-designs-around-relevant-endpoints/  |
# ✓ | ⏱: 0.13s
# [COMPLETE] ● https://www.clinicaltrialsarena.com/features/dmd...s-on-building-designs-around-relevant-endpoints/  |
# ✓ | ⏱: 70.62s
# [FETCH]... ↓ https://www.clinicaltrials.gov/study/NCT01603407                                                     |
# ✓ | ⏱: 68.99s
# [SCRAPE].. ◆ https://www.clinicaltrials.gov/study/NCT01603407                                                     |
# ✓ | ⏱: 0.61s
# [COMPLETE] ● https://www.clinicaltrials.gov/study/NCT01603407                                                     |
# ✓ | ⏱: 69.60s
# [FETCH]... ↓ https://www.clinicaltrials.gov/study/NCT03443115                                                     |
# ✓ | ⏱: 71.32s
# [SCRAPE].. ◆ https://www.clinicaltrials.gov/study/NCT03443115                                                     |
# ✓ | ⏱: 0.30s
# [COMPLETE] ● https://www.clinicaltrials.gov/study/NCT03443115                                                     |
# ✓ | ⏱: 71.62s
# [FETCH]... ↓ https://www.rarediseaseadvisor.com/hcp-resource/duchenne-muscular-dystrophy-clinical-trials/         |
# ✓ | ⏱: 71.62s
# [SCRAPE].. ◆ https://www.rarediseaseadvisor.com/hcp-resource/duchenne-muscular-dystrophy-clinical-trials/         |
# ✓ | ⏱: 0.17s
# [COMPLETE] ● https://www.rarediseaseadvisor.com/hcp-resource/duchenne-muscular-dystrophy-clinical-trials/         |
# ✓ | ⏱: 71.79s
# [FETCH]... ↓ https://www.nature.com/articles/s41591-024-03304-z                                                   |
# ✓ | ⏱: 71.82s
# [SCRAPE].. ◆ https://www.nature.com/articles/s41591-024-03304-z                                                   |
# ✓ | ⏱: 0.66s
# [COMPLETE] ● https://www.nature.com/articles/s41591-024-03304-z                                                   |
# ✓ | ⏱: 72.48s
# [FETCH]... ↓ https://onlinelibrary.wiley.com/doi/abs/10.1002/ppul.25079                                           |
# ✓ | ⏱: 72.61s
# [SCRAPE].. ◆ https://onlinelibrary.wiley.com/doi/abs/10.1002/ppul.25079                                           |
# ✓ | ⏱: 0.53s
# [COMPLETE] ● https://onlinelibrary.wiley.com/doi/abs/10.1002/ppul.25079                                           |
# ✓ | ⏱: 73.14s
# Completed iteration 10, remaining budget: 5
# Completeness check start.
# Completeness check: True, reasoning: All major and mandatory scope areas from the guideline—including disease definition, genetic/phenotypic correlations, cardiopulmonary burden, clinical care recommendations, regulatory/label status, ongoing investigational trials, and evidence gaps—are addressed by high-quality, citable sources; significant knowledge gaps do not remain, and the survey achieves comprehensive, guideline-concordant coverage.
# Literature search deemed complete by completeness checker
# Survey completed with 5 responses
# ✅ Result saved to output/action_item_7_literature_search_response_2.json

# %%
# Identify key insight for each rag response

# The goal of key insight identification is to identify the most important insight from the RAG response. Think of it as a one sentence summary of the RAG response that is most important to the question. The reason we do this is to help us reduce the noise in the rag responses and focus on the most important information when determing the final report outline.

class KeyInsightIdentifier(dspy.Signature):
    """
    You are GENERTING exactly ONE (1) KEY INSIGHT from the RAG repsonse. 
    It must be ONE sentence only, no more, no less. 

    REQURIEMENTS:
    - Directly answers the question, not vague.
    - Names actors and actions, incl time/place if avaible.
    - If there is a number/trend in the answer include it.
    - Keep inline [n] citations exactly as shown, do NOT change them.
    - No hedging like "maybe" or "could". No meta talk.
    - If no good fact is in the answer, return: "Insufficient evidence in retrieved sources to answer the question."
    """
    question: str = dspy.InputField(
        desc="The question that was asked"
    )
    question_context: str = dspy.InputField(
        desc="The context of the question"
    )
    answer: str = dspy.InputField(
        desc="The answer to the question aggregating information from external sources"
    )
    key_insight: str = dspy.OutputField(
        desc="One sentence key insight."
    )

key_insight_identifier = dspy.Predict(KeyInsightIdentifier)
key_insight_identifier_lm = init_lm(LanguageModelProviderConfig(
    provider=LanguageModelProvider.LANGUAGE_MODEL_PROVIDER_LITELLM_SERVER,
    model_name="gpt-4.1-mini", # NOTE: should we use a more powerful model? You can play around with it.
    temperature=1.0,
    max_tokens=10000,
    litellm_server_config=LiteLLMServerConfig(api_key=os.getenv("LITELLM_API_KEY"), api_base=os.getenv("LITELLM_API_BASE"))
))


for rag_response in tqdm(rag_responses):
    with dspy.context(lm=key_insight_identifier_lm):
        rag_response.key_insight = (await key_insight_identifier.aforward(
            question=rag_response.question,
            question_context=rag_response.question_context,
            answer=rag_response.answer
        )).key_insight

with open("output/action_item_7_rag_responses_with_key_insight.json", "w") as f:
    json.dump([rag_response.to_dict() for rag_response in rag_responses], f, indent=2)

for rag_response in rag_responses:
    print(rag_response.key_insight + "\n")
print(f"✅ Result saved to output/action_item_7_rag_responses_with_key_insight.json")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:16<00:00,  1.37s/it]
# Reputable datasets and reports from the Ukrainian Air Force, CSIS, ACLED, ISW, and UN document that from 2022 to 2024, Russia conducted extensive drone strike campaigns across Ukraine, including in Donetsk and Kyiv, with confirmed launches exceeding 14,700 attack drones and over 19,000 missiles, reaching peak monthly drone launches of over 6,400 in July 2025 and causing significant civilian casualties [1][2][3][4][5][6][8].
#
# No primary sources or Tier-1 newswires from 2022 to 2024 provide evidence of Russian Air Force drone operations in transnational contexts such as Ar Raqqa, Rural Damascus, or Lattakia, including details on dates, strike counts, or campaign intent.
#
# Between 2022 and 2024, reputable organizations like the ISW, IISS, CSIS, CNAS, the Belfer Center, and West Point highlight that Russian Air Force drone campaign data suffer from significant methodological challenges including reliance on incomplete open-source intelligence, varied drone types complicating counts, electronic warfare effects reducing operational precision, and quality declines due to sanctions-driven component substitutions, which collectively limit the precision, coverage, and reliability of campaign assessments [1][2][3][www.csis.org][drones.cnas.org][www.russiamatters.org][ctc.westpoint.edu].
#
# No Tier-1 newswire or primary dataset sources from 2022 to 2024 provide direct, citable evidence of Russian Air Force drone strike operations in transnational theaters such as Ar Raqqa, Rural Damascus, or Lattakia, with all documented strikes exclusively occurring in Ukraine.
#
# The Saratoga Foundation and Nest Centre reports from late 2024 critically analyze Russia’s doctrinal shift by formally establishing the Unmanned Systems Forces (VBS) as a central pillar of warfare, with Defense Minister Andrei Belousov explicitly linking this to lessons from the Ukraine conflict and signaling a strategic intent to integrate unmanned capabilities into multi-theater power projection [1][2].
#
# No primary datasets or reputable organizational reports such as SIPRI or Jane’s provide documented evidence—dates, actors, or strike counts—of Russian Air Force drone operations in Ar Raqqa, Rural Damascus, or Lattakia between 2022 and 2024.
#
# From 2022 to 2024, Russian Air Force drone activities documented in multilingual regional and Syrian local media archives focused on defensive engagements and attacks near the Hmeimim Air Base in Latakia, including notable drone strikes on October 3 and February 18, 2024, but no offensive Russian drone strikes were reported in Ar Raqqa, rural Damascus, or other comparable Syrian theaters[1][2][3][4][5].
#
# From 2022 to 2024, ACLED recorded over 290 drone strikes in Sudan with detailed fatality counts, Explosive Weapons Monitor reported 791 explosive weapon incidents causing 4,819 casualties (91% civilians) in December 2024 alone, and SIPRI alongside the Drone Wars UK database provide aggregated fatality figures and detailed strike-level data respectively, collectively offering comprehensive quantitative counts of drone and artillery-related incidents and their fatality rates in global conflict zones [acleddata.com][explosiveweaponsmonitor.org][sipri.org][dronewars.github.io].
#
# Between 2022 and 2024, tier-1 outlets reported that Russia and Ukraine’s shift to attrition warfare, relying on expendable munitions and sustained manpower mobilization, caused extensive psychological trauma, resource depletion, and chronic societal disruption in civilian populations amidst static frontlines and cyber warfare impacts [1][2][3][4].
#
# The ACLED dataset for 2022–2024 drone and artillery strikes reveals key limitations including underreporting of incidents due to reliance on secondary media sources with urban bias, conservative fatality coding that assigns default counts (3 or 10) in uncertain cases leading to potential underestimation, and variable geographic precision often defaulting to administrative centers, all of which hinder accurate and granular conflict analysis[1][2][3].
#
# No event-level sources from ACLED, SIPRI, or tier-1 outlets explicitly state or provide a median fatality per drone or artillery attack of zero for 2022–2024, and no exact quoted passage substantiates this claim.
#
# From 2022 to 2024, multiple reputable sources documented significant mass-casualty remote strikes with median fatalities above zero, including 80 Tigray drone and aerial bombardment incidents causing 1,143 casualties with one-third fatal, over 800 civilian harm incidents in Gaza with over one-third involving ten+ deaths, and over 3,000 civilian casualties from Ukrainian short-range drone attacks with a record 42 fatalities in one month [pmc.ncbi.nlm.nih.gov][gaza-patterns-harm.airwars.org][ukraine.ohchr.org].
#
# ✅ Result saved to output/action_item_7_rag_responses_with_key_insight.json

# %%
# Final report title and guideline proposal
# We will generate a TITLE + bullet GUIDELINE for the final rare-disease article.
# The guideline must mirror our target article structure.

class FinalWritingGuidelineProposal(dspy.Signature):
    """
    You are GENERATING a patient-education rare/orphan disease article TITLE
    and a bullet-format WRITING GUIDELINE using:
    - the selected theses (core claims we want to support),
    - and key_insights extracted from RAG.

    REQUIREMENTS FOR TITLE:
    - 8–14 words.
    - Headline/title case.
    - No colon, no question mark.
    - Must contain the disease name if it is obvious from theses/insights.
    - Tone: educational, not sensational (“Understanding…”, “Overview of…”, “Key Features of…” are okay).

    REQUIREMENTS FOR GUIDELINE:
    - Output MUST be bullet points only (no prose paragraph).
    - Each bullet should map to a section we will later fill, in this order:
        1) Brief definition/what the disease is
        2) Genetic/etiologic basis (tie to theses if about mutations)
        3) Clinical picture (signs/symptoms, progression)
        4) Diagnosis/confirmation (esp. molecular diagnostics if mentioned in theses)
        5) Management/treatment landscape (summarize, do NOT prescribe; mention steroids/exon skipping only if present in theses/insights)
        6) Prognosis/natural history / impact on quality of life
        7) Current research/therapies in development
        8) Gaps/uncertainties (“What is not known”)
    - Where a thesis or key insight contains a citation marker like [1], preserve it on the bullet that uses that info.
    - If multiple theses overlap (e.g. DMD genetics + therapy access), merge them into a single coherent flow.
    - Explicitly add a safety/education bullet: “This report is for education only and does not replace clinical advice.”

    CONTENT RULE:
    - Use ONLY information that can be traced to selected_theses or key_insights; do NOT invent new clinical facts.
    - If a thesis mentions barriers (cost/access), add a bullet under “Current research / health systems considerations”.
    """
    # Inputs
    selected_theses: List[str] = dspy.InputField(
        desc="2–3 core theses about the disease (genetics, progression, therapy)."
    )
    key_insights: List[str] = dspy.InputField(
        desc="Key insights from RAG for this disease; may include diagnostics, therapy notes, or unmet needs."
    )

    # Outputs
    report_thesis: str = dspy.OutputField(
        desc="One headline-style title (8–14 words), disease-focused, no colon."
    )
    writing_guideline: str = dspy.OutputField(
        desc=(
            "Bullet-only guideline, ordered as: definition, genetics/etiology, clinical features, diagnosis, "
            "management/treatment, prognosis/impact, research/current trials, gaps/unknowns, safety note. "
            "Preserve any inline [n] citations from inputs."
        )
    )


# model init stays the same
final_writing_guideline_proposal = dspy.Predict(FinalWritingGuidelineProposal)
final_writing_guideline_proposal_lm = init_lm(LanguageModelProviderConfig(
    provider=LanguageModelProvider.LANGUAGE_MODEL_PROVIDER_LITELLM_SERVER,
    model_name="gpt-4.1",
    temperature=1.0,
    max_tokens=10000,
    litellm_server_config=LiteLLMServerConfig(
        api_key=os.getenv("LITELLM_API_KEY"),
        api_base=os.getenv("LITELLM_API_BASE")
    )
))

with dspy.context(lm=final_writing_guideline_proposal_lm):
    final_writing_guideline_proposal_response = await final_writing_guideline_proposal.aforward(
        selected_theses=selected_theses,
        key_insights=[rr.key_insight for rr in rag_responses],
    )

final_writing_thesis = final_writing_guideline_proposal_response.report_thesis
final_writing_guideline = final_writing_guideline_proposal_response.writing_guideline

with open("output/action_item_7_final_writing_guideline_proposal.json", "w") as f:
    json.dump({
        "report_thesis": final_writing_thesis,
        "writing_guideline": final_writing_guideline
    }, f, indent=2)

print(f"report title: {final_writing_thesis}\n")
print(f"writing guideline:\n{final_writing_guideline}")
print("✅ Result saved to output/action_item_7_final_writing_guideline_proposal.json")
# Out:
# report title: Understanding Duchenne Muscular Dystrophy: Genetics, Diagnosis, and Clinical Progression
#
# writing guideline:
# - Duchenne Muscular Dystrophy (DMD) is a rare genetic condition characterized by progressive muscle wasting and weakness.
# - DMD is caused by mutations (deletions or duplications) in the DMD gene; over 95% of diagnosed cases show changes in this locus (Emery, 2023).
# - The clinical course involves worsening muscle function and frequent cardiac involvement; progression often leads to reduced life expectancy (Mendell et al., 2016).
# - Diagnosis relies on molecular protocols to confirm DMD gene mutations; genetic testing is essential in clinical settings.
# - Current management prioritizes multidisciplinary care, with a special emphasis on cardiopulmonary support in pediatric neuromuscular clinics.
# - Prognosis is shaped by the rate of muscle and cardiac deterioration, affecting mobility and overall quality of life.
# - Research is ongoing to address gaps in cardiopulmonary care and optimize early molecular diagnosis.
# - Uncertainties remain regarding optimal timing for interventions and long-term outcomes as care standards evolve.
# - This report is for education only and does not replace clinical advice.
# ✅ Result saved to output/action_item_7_final_writing_guideline_proposal.json

# %%
def _normalize_rag_response_citation_indices(rag_responses: List[RagResponse]) -> Tuple[List[str], List[RetrievedDocument]]:
        """
        Normalize citation indices across multiple RAG (retrieval-augmented generation) responses.

        Each `RagResponse` contains:
        - `answer`: a string with inline citations like [1], [2], ...
        - `cited_documents`: the list of documents those citations refer to

        Problem:
        Citation indices restart at [1] for every response, but when combining answers,
        we want all citations to point to a single global list of retrieved documents.

        What this function does:
        1. Iterates over all RAG responses in order.
        2. Shifts the local citation indices in each answer so that they correctly map
            into the combined list of all retrieved documents.
            - For example, if the first response cited 3 docs ([1], [2], [3]),
            then the second response’s citations start at [4], not [1].
        3. Prefixes each updated answer with its corresponding sub-question for clarity.
        4. Returns:
            - A list of normalized answers (with corrected citation indices).
            - The flattened list of all retrieved documents in the proper order.

        Example:
            Input (two RAG responses):
                R1: "Paris is in France [1].", docs=[docA]
                R2: "Berlin is in Germany [1].", docs=[docB]

            Output:
                answers = [
                "Sub-question: ...\nAnswer: Paris is in France [1].",
                "Sub-question: ...\nAnswer: Berlin is in Germany [2]."
                ]
                documents = [docA, docB]
        """
        all_documents: List[RetrievedDocument] = []
        all_updated_answers: List[str] = []
        for idx, rag_response in enumerate(rag_responses):
            citation_offset = len(all_documents)
            updated_answer = rag_response.answer
            for i in range(len(rag_response.cited_documents)):
                updated_answer = updated_answer.replace(f"[{i+1}]", f"[tmp_{citation_offset+i+1}]")
            for i in range(len(rag_response.cited_documents)):
                updated_answer = updated_answer.replace(f"[tmp_{citation_offset+i+1}]", f"[{citation_offset+i+1}]")

            all_updated_answers.append(
                f"Sub-question: {rag_response.question}\nAnswer: {updated_answer}\n")
            all_documents.extend(rag_response.cited_documents)
        return all_updated_answers, all_documents

# %%
# Final report synthesis
# We will synthesize the final rare-disease article using the generated title, guideline, and RAG responses.

class FinalReportSynthesizer(dspy.Signature):
    """
    You are composing a patient-education RARE/ORPHAN DISEASE ARTICLE using:
    - a report title,
    - a section-by-section writing guideline,
    - and normalized RAG-sourced information with inline numeric citations.

    CORE GOAL:
    - Produce a markdown article that follows the guideline's section order.
    - Make it clear, accurate, and explicit about uncertainties.
    - Do NOT give medical advice; describe current knowledge only.

    STRUCTURE RULES:
    - Start with the provided title as an H1 (# ...).
    - Immediately follow with the education/safety note:
      "This article is for education only and does not replace advice from your clinician."
    - Then create sections in the exact order implied by `writing_guideline`.
    - Use markdown headings (#, ##, ###) to reflect hierarchy.
    - If the guideline mentions sections like "What Is Not Known", include them.

    CONTENT INTEGRATION RULES:
    - Merge all relevant RAG answers into the correct sections; do not leave content floating.
    - If multiple RAG items repeat the same fact, keep the clearest one.
    - If RAG indicates limited evidence, state that explicitly in the "What Is Not Known"/limitations section.
    - Do NOT introduce information that is not present in `gathered_information` or obviously implied by the selected theses/guideline.

    WRITING STYLE:
    - Patient-friendly, ~9th–10th grade, but still precise.
    - Short paragraphs; use bulleted lists for symptoms, tests, or resources if the guideline suggests it.
    - Neutral, non-alarmist tone.
    - Do NOT prescribe or recommend doses.

    CITATION POLICY (STRICT)

        1. Allowed format
           - Only numeric inline citations are allowed: [1], [2], [3], ...
           - Do NOT output URLs, domains, or alphanumeric IDs inside brackets (e.g. no [pmc.ncbi.nlm.nih.gov], no [FDA-2024], no [Orphanet]).
           - If the source text you were given contains non-numeric citations, DROP them unless a numeric ID for the same fact is also present.
        
        2. Source of truth
           - Assume that `gathered_information` has already had its citation numbers normalized by the pipeline.
           - You MUST reuse these numeric IDs exactly as they appear in `gathered_information`.
           - You MUST NOT invent new numbers or renumber globally.
        
        3. Where to place citations
           - Attach the citation immediately after the fact/number/name it supports.
           - Example: “DMD is caused by mutations in the DMD gene on Xp21.2.[1]”
           - Not allowed: putting all citations at the end of the paragraph.
           - Not allowed: “... Xp21.2 [1].” (space before bracket) → prefer “Xp21.2.[1]”
        
        4. How many citations per fact
           - Default to 1 citation per fact.
           - You may use 2 citations only when:
             a) the fact combines two distinct claims that both had citations in `gathered_information`, or
             b) you are showing that multiple guideline documents agree.
           - Maximum allowed at once: 3.
           - If the source text had a long chain like [1][2][13][30][31], shorten it to the 1–2 MOST RELEVANT numbers for that sentence.
        
        5. Conflicting or duplicate citations
           - If two sentences in `gathered_information` cite the same number for the same claim, you may keep only the first instance in your synthesized paragraph.
           - Do not show the same citation number 3 times in the same paragraph unless the paragraph truly has 3 different claims from that source.
        
        6. Non-numeric or malformed citations
           - If you encounter a citation like “[pmc.ncbi.nlm.nih.gov]” or “[FDA page]” in the input:
             - Try to find the nearest numeric citation for the same idea in the same input block and use that instead.
             - If there is no numeric match, omit that citation completely and keep the sentence only if it is well supported elsewhere in the same paragraph.
             - Do NOT output the malformed citation.
        
        7. Ascending order within a sentence
           - If a sentence must keep more than one citation, order them ascending: “[1][5]” not “[5][1]”.
           - Do not renumber across the entire document—just sort the ones you are actually using in that spot.
        
        8. Missing support
           - If you cannot find any numeric citation in `gathered_information` that supports a sentence you are writing, REMOVE that sentence instead of inventing a citation.
        
        9. Section-level claims
           - For generic, well-supported section intros that summarize multiple cited sentences in `gathered_information`, use the earliest applicable citation number for that section.
           - Example: if all the DMD natural history claims in the inputs use [23], [24], [25], open the prognosis section with “[23]” or “[23][24]”, not with a new number.
        
        10. No cross-section recycling
           - Do not copy a citation number from a therapy paragraph into a genetics paragraph if the original source in `gathered_information` did not talk about genetics.
           - Keep citations tied to the topic they originally supported.


    CONTENT CONSTRAINTS:
    - Constrain content to provided information.
    - Do not speculate or add external knowledge.
    - If something is missing (e.g., no management info), add a one-line note: "Limited management information was available in the retrieved sources." and keep it citation-free.
    """

    report_thesis: str = dspy.InputField(
        desc="The article/report title that should appear as H1."
    )
    writing_guideline: str = dspy.InputField(
        desc="Bullet-format guideline listing the sections and key points, in order."
    )
    gathered_information: str = dspy.InputField(
        desc="All RAG answers with normalized inline citations, newline-separated."
    )
    report_style: str = dspy.InputField(
        desc="Optional style hint, e.g. 'patient-friendly, concise, no medical advice'.",
        default="patient-friendly, concise, no medical advice"
    )

    final_report: str = dspy.OutputField(
        desc="The final rare-disease article in markdown, with H1 title, safety note, and ordered sections."
    )


final_report_synthesizer = dspy.Predict(FinalReportSynthesizer)
final_report_synthesizer_lm = init_lm(LanguageModelProviderConfig(
    provider=LanguageModelProvider.LANGUAGE_MODEL_PROVIDER_LITELLM_SERVER,
    model_name="gpt-5-mini",
    temperature=1.0,
    max_tokens=20000,
    litellm_server_config=LiteLLMServerConfig(
        api_key=os.getenv("LITELLM_API_KEY"),
        api_base=os.getenv("LITELLM_API_BASE")
    )
))

# normalize citations from RAG (your existing helper)
all_updated_answers, all_documents = _normalize_rag_response_citation_indices(rag_responses)
gathered_information = "\n".join(all_updated_answers)

with dspy.context(lm=final_report_synthesizer_lm):
    final_report = (await final_report_synthesizer.aforward(
        report_thesis=final_writing_thesis,
        writing_guideline=final_writing_guideline,
        gathered_information=gathered_information,
        report_style="patient-friendly, preserve section order, no medical advice"
    )).final_report

with open("output/action_item_7_final_report_raw.md", "w") as f:
    f.write(final_report)
print("✅ Result saved to output/action_item_7_final_report_raw.md")
# Out:
# ✅ Result saved to output/action_item_7_final_report_raw.md

# %%
# TODO: manually add bibliography to the final report. Review the output. Adjust the prompt and rerun the report synthesis if necessary. Make sure it has title, executive summary, sections with desired inline citations, and bibliography.

bibliography = "# Bibliography \n\n"
for index, doc in enumerate(all_documents, 1):
    bibliography += f"{index}. **{doc.title}**. Available at: {doc.url}\n"

final_report_with_bibliography = final_report + "\n\n" + bibliography

with open("output/action_item_7_final_report.md", "w") as f:
    f.write(final_report_with_bibliography)
print(f"✅ Result saved to output/action_item_7_final_report.md")
# Out:
# ✅ Result saved to output/action_item_7_final_report.md

# %% [markdown]
# **Review the generated report. Reflect on what are weaknesses and explain in detail how would you plan to improve it.**

# %%
weaknesses_and_improvements = """
Weakness:
- Citations were a bit iffy, with the generated report sometimes including URLS when explicitly instructed not to or not following correctly
the citation format. 
- Sections within sections aren't really used in the report, we only really have overarching sections (such as Methods, etc) but no further 
fragmentation within them. This isn't really in line with what we see in modern literature.
- Our report doesn't seem to utilize explicit statistics from our database crawls, instead it gestures at "increases" but doesn't give
concrete numbers. This indicates we might not be properly leveraging our database insights.


Improvements:
- Make more explicit instructions so that the system creates citations that better reflect our standards.
- Define how we can further fragment the report so that we have subsections as desired
- Have the report use specific statistics from our database crawls, perhaps via better employed input fields for this data.

"""

with open("output/action_item_7_weaknesses_and_improvements.md", "w") as f:
    f.write(weaknesses_and_improvements)
print(f"✅ Result saved to output/action_item_7_weaknesses_and_improvements.md")
# Out:
# ✅ Result saved to output/action_item_7_weaknesses_and_improvements.md

# %% [markdown]
# ## Create submission

# %%
! python create_submission.py
# Out:
# CS224V HW1 Submission Creator
# ==================================================
# 🔄 Converting notebook to PDF: notebook.ipynb -> notebook.pdf
# ❌ Error converting notebook to PDF: Command '['jupyter', 'nbconvert', '--to', 'pdf', '--output', 'notebook.pdf', 'notebook.ipynb']' returned non-zero exit status 1.
# stderr: [NbConvertApp] Converting notebook notebook.ipynb to pdf
# [NbConvertApp] ERROR | Error while converting 'notebook.ipynb'
# Traceback (most recent call last):
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages/nbconvert/nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages/nbconvert/exporters/templateexporter.py", line 390, in from_filename
#     return super().from_filename(filename, resources, **kw)  # type:ignore[return-value]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages/nbconvert/exporters/exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages/nbconvert/exporters/templateexporter.py", line 396, in from_file
#     return super().from_file(file_stream, resources, **kw)  # type:ignore[return-value]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages/nbconvert/exporters/exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages/nbconvert/exporters/pdf.py", line 184, in from_notebook_node
#     latex, resources = super().from_notebook_node(nb, resources=resources, **kw)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages/nbconvert/exporters/latex.py", line 92, in from_notebook_node
#     return super().from_notebook_node(nb, resources, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages/nbconvert/exporters/templateexporter.py", line 429, in from_notebook_node
#     output = self.template.render(nb=nb_copy, resources=resources)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages/jinja2/environment.py", line 1295, in render
#     self.environment.handle_exception()
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages/jinja2/environment.py", line 942, in handle_exception
#     raise rewrite_traceback_stack(source=source)
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/share/jupyter/nbconvert/templates/latex/index.tex.j2", line 8, in top-level template code
#     ((* extends cell_style *))
#     ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/share/jupyter/nbconvert/templates/latex/style_jupyter.tex.j2", line 176, in top-level template code
#     \prompt{(((prompt)))}{(((prompt_color)))}{(((execution_count)))}{(((extra_space)))}
#     ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/share/jupyter/nbconvert/templates/latex/base.tex.j2", line 7, in top-level template code
#     ((*- extends 'document_contents.tex.j2' -*))
#     ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/share/jupyter/nbconvert/templates/latex/document_contents.tex.j2", line 51, in top-level template code
#     ((*- block figure scoped -*))
#     ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/share/jupyter/nbconvert/templates/latex/display_priority.j2", line 5, in top-level template code
#     ((*- extends 'null.j2' -*))
#     ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/share/jupyter/nbconvert/templates/latex/null.j2", line 30, in top-level template code
#     ((*- block body -*))
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/share/jupyter/nbconvert/templates/latex/base.tex.j2", line 241, in block 'body'
#     ((( super() )))
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/share/jupyter/nbconvert/templates/latex/null.j2", line 32, in block 'body'
#     ((*- block any_cell scoped -*))
#     ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/share/jupyter/nbconvert/templates/latex/null.j2", line 85, in block 'any_cell'
#     ((*- block markdowncell scoped-*)) ((*- endblock markdowncell -*))
#     ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/share/jupyter/nbconvert/templates/latex/document_contents.tex.j2", line 68, in block 'markdowncell'
#     ((( cell.source | citation2latex | strip_files_prefix | convert_pandoc('markdown+tex_math_double_backslash', 'json',extra_args=[]) | resolve_references | convert_explicitly_relative_paths | convert_pandoc('json','latex'))))
#     ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages/nbconvert/filters/pandoc.py", line 36, in convert_pandoc
#     return pandoc(source, from_format, to_format, extra_args=extra_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages/nbconvert/utils/pandoc.py", line 50, in pandoc
#     check_pandoc_version()
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages/nbconvert/utils/pandoc.py", line 98, in check_pandoc_version
#     v = get_pandoc_version()
#         ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jrizo/miniconda3/envs/cs224v_hw1/lib/python3.11/site-packages/nbconvert/utils/pandoc.py", line 75, in get_pandoc_version
#     raise PandocMissing()
# nbconvert.utils.pandoc.PandocMissing: Pandoc wasn't found.
# Please check that pandoc is installed:
# https://pandoc.org/installing.html
#
#
# Trying alternative method with --no-input flag...
# ❌ Failed to convert notebook to PDF: Command '['jupyter', 'nbconvert', '--to', 'pdf', '--no-input', '--output', 'notebook.pdf', 'notebook.ipynb']' returned non-zero exit status 1.
# Please install required dependencies:
#   pip install nbconvert
#   # For PDF conversion:
#   # macOS: brew install --cask mactex
#   # or: pip install 'nbconvert[webpdf]'
#
# 📋 Checking required files:
# ✅ Main assignment notebook: notebook.ipynb (1685699 bytes)
# ✅ Action Item 3: Basic RAG response: output/action_item_3_rag_response.json (24307 bytes)
# ✅ Action Item 3: Recency-focused RAG response: output/action_item_3_rag_response_recency.json (19275 bytes)
# ✅ Action Item 3: Recency analysis comments: output/action_item_3_rag_response_recency_comment.json (2805 bytes)
# ✅ Action Item 3: Technical depth RAG response: output/action_item_3_rag_response_depth.json (20858 bytes)
# ✅ Action Item 3: Technical depth analysis comments: output/action_item_3_rag_response_depth_comment.json (1460 bytes)
# ✅ Action Item 4: Literature search response: output/action_item_4_literature_search_response.json (337923 bytes)
# ✅ Action Item 4: Literature search analysis comments: output/action_item_4_literature_search_response_comment.json (2670 bytes)
# ✅ Action Item 5: Database exploration analysis comments: output/action_item_5_comments.json (2685 bytes)
# ✅ Action Item 6: Selected theses: output/action_item_6_selected_theses.json (759 bytes)
# ✅ Action Item 7: Literature search response 1: output/action_item_7_literature_search_response_1.json (213376 bytes)
# ✅ Action Item 7: Literature search response 2: output/action_item_7_literature_search_response_2.json (197029 bytes)
# ✅ Action Item 7: RAG responses with key insights: output/action_item_7_rag_responses_with_key_insight.json (409672 bytes)
# ✅ Action Item 7: Raw final report: output/action_item_7_final_report_raw.md (12152 bytes)
# ✅ Action Item 7: Final investigative report: output/action_item_7_final_report.md (19016 bytes)
# ✅ Action Item 7: Weaknesses and improvements: output/action_item_7_weaknesses_and_improvements.md (968 bytes)
#
# 📦 Creating submission zip: cs224v_hw1_submission.zip
#    Added: notebook.ipynb
#    Added: output/action_item_3_rag_response.json
#    Added: output/action_item_3_rag_response_recency.json
#    Added: output/action_item_3_rag_response_recency_comment.json
#    Added: output/action_item_3_rag_response_depth.json
#    Added: output/action_item_3_rag_response_depth_comment.json
#    Added: output/action_item_4_literature_search_response.json
#    Added: output/action_item_4_literature_search_response_comment.json
#    Added: output/action_item_5_comments.json
#    Added: output/action_item_6_selected_theses.json
#    Added: output/action_item_7_literature_search_response_1.json
#    Added: output/action_item_7_literature_search_response_2.json
#    Added: output/action_item_7_rag_responses_with_key_insight.json
#    Added: output/action_item_7_final_report_raw.md
#    Added: output/action_item_7_final_report.md
#    Added: output/action_item_7_weaknesses_and_improvements.md
#
# ✅ SUCCESS!
# Submission created: cs224v_hw1_submission.zip (501,709 bytes)
# Total files included: 16
#
# 📋 Zip file contents:
#    notebook.ipynb (1,685,699 bytes)
#    output/action_item_3_rag_response.json (24,307 bytes)
#    output/action_item_3_rag_response_recency.json (19,275 bytes)
#    output/action_item_3_rag_response_recency_comment.json (2,805 bytes)
#    output/action_item_3_rag_response_depth.json (20,858 bytes)
#    output/action_item_3_rag_response_depth_comment.json (1,460 bytes)
#    output/action_item_4_literature_search_response.json (337,923 bytes)
#    output/action_item_4_literature_search_response_comment.json (2,670 bytes)
#    output/action_item_5_comments.json (2,685 bytes)
#    output/action_item_6_selected_theses.json (759 bytes)
#    output/action_item_7_literature_search_response_1.json (213,376 bytes)
#    output/action_item_7_literature_search_response_2.json (197,029 bytes)
#    output/action_item_7_rag_responses_with_key_insight.json (409,672 bytes)
#    output/action_item_7_final_report_raw.md (12,152 bytes)
#    output/action_item_7_final_report.md (19,016 bytes)
#    output/action_item_7_weaknesses_and_improvements.md (968 bytes)
#
# 🎉 Ready to submit: cs224v_hw1_submission.zip

# %% [markdown]
# ## Appendix
#
# ### Database Exploration Agent Implementation
#
# > **Note:** This implementation is provided for reference purposes. Utilize the pre-computed results in Action Item 5 for efficient completion of the assignment.
#
# ---

# %%
# API endpoint URL
api_url = "https://cs224v-database-agent.genie.stanford.edu/database-exploration"

# Prepare the request payload
payload = {
    "topic": TOPIC,
    "seed_questions": seed_questions,
    "lm_config": database_exploration_lm_config.to_dict()
}

# NOTE: uncomment the code below to make the request

# print("Making request to database exploration endpoint... Might take up to 30 minutes")
# async with httpx.AsyncClient(timeout=6000.0) as client:
#     r = await client.post(api_url, json=payload)
#     r.raise_for_status()
#     database_exploration_response = r.json()

# with open("output/action_item_5_database_exploration.json", "w") as f:
#     json.dump(database_exploration_response, f, indent=2)

# print(f"✅ Result saved to output/action_item_5_database_exploration.json")
